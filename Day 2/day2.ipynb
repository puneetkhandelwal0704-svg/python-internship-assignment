# %%
l=[]
print(l,type(l))
# Out:
# [] <class 'list'>

# %%
l=[10,20,30,40]
l2=["A",40,"B","C",60]
print(l2,type(l2))
# Out:
# ['A', 40, 'B', 'C', 60] <class 'list'>

# %%
l=[10,20,30,40]
l2=["A",40,"B","C",60]
print(l2[1:4],type(l2))
# Out:
# [40, 'B', 'C'] <class 'list'>

# %%
L=[10,20,30,40]
print(L[-1::-1],type(L)) 

for i in range(4):
    print(L[i]*2)
# Out:
# [40, 30, 20, 10] <class 'list'>
# 20
# 40
# 60
# 80

# %%
L=[10,20,30,40]
l2=["A",40,"B","C",60]
print(L[-1::-1],type(L)) 

for x in l2:
    print(x)
# Out:
# [40, 30, 20, 10] <class 'list'>
# A
# 40
# B
# C
# 60

# %%
L=[10,20,30,40]
l2=["A",40,"B","C",60]
print(L[-1::-1],type(L)) 
c=len(L)

s=0
for x in L:
    s=s+x
print(s)
# Out:
# [40, 30, 20, 10] <class 'list'>
# 100

# %%
L=[10,20,30,40]
l2=["A",40,"B","C",60]
print(L[-1::-1],type(L)) 

max=L[0]
for x in L:
    if x>max:
        max=x
print(max)
# Out:
# [40, 30, 20, 10] <class 'list'>
# 40

# %%
str="Python is a programming language"
l=str.split()
print(l,type[l])
# Out:
# ['Python', 'is', 'a', 'programming', 'language'] type[['Python', 'is', 'a', 'programming', 'language']]

# %%
str="Python is a programming language"
l=str.split()
l.append("20")
print(l)
# Out:
# ['Python', 'is', 'a', 'programming', 'language', '20']

# %%
str="Python is a programming language"
l=str.split()
for i in range(4,8):
    l.append(i)
    print(l)
# Out:
# ['Python', 'is', 'a', 'programming', 'language', 4]
# ['Python', 'is', 'a', 'programming', 'language', 4, 5]
# ['Python', 'is', 'a', 'programming', 'language', 4, 5, 6]
# ['Python', 'is', 'a', 'programming', 'language', 4, 5, 6, 7]

# %%
str="Python is a programming language"
l=str.split()
l2=[100,20,390,40,500]
l.append(l2)
print(l)
# Out:
# ['Python', 'is', 'a', 'programming', 'language', [100, 20, 390, 40, 500]]

# %%
str="Python is a programming language"
l=str.split()
l2=[100,20,390,40,500]
l.insert(0,l2)
print(l)
# Out:
# [[100, 20, 390, 40, 500], 'Python', 'is', 'a', 'programming', 'language']

# %%
str="Python is a programming language"
l=str.split()
l2=[100,20,390,40,500]
l.extend(l2)
#l.remove("a")
#l.pop(-1)
l.reverse()
print(l)
# Out:
# [500, 40, 390, 20, 100, 'language', 'programming', 'a', 'is', 'Python']

# %%
str="Python is a programming language"
l=str.split()
l2=[100,20,390,40,500]
l2.sort()
print(l2)
# Out:
# [20, 40, 100, 390, 500]

# %%
str="Python is a programming language"
l=str.split()
l2=[100,20,390,40,500]
l2.copy()
print(l2)
# Out:
# [100, 20, 390, 40, 500]

# %%
d={"Name":"Python","Type":"Programming Language","Version":3.10}
print(d,type(d))
# Out:
# {'Name': 'Python', 'Type': 'Programming Language', 'Version': 3.1} <class 'dict'>

# %%
d={"Name":"Python","Type":"Programming Language","Version":3.10, 'd2':{"Name":"abc","type":"xyz","mrp":1000}}
print(d["d2"]["Name"])
# Out:
# abc

# %%
d={}
d['Alpha']="A"
print(d)
# Out:
# {'Alpha': 'A'}

# %%
d={"Name":"Python","Type":"Programming Language","Version":3.10, 'd2':{"Name":"abc","type":"xyz","mrp":1000}}
#print(d)
d.clear()
print(d)
# Out:
# {}

# %%
d={"Name":"Python","Type":"Programming Language","Version":3.10, 'd2':{"Name":"abc","type":"xyz","mrp":1000}}
d["d2"].keys()
# Out:
# dict_keys(['Name', 'type', 'mrp'])

# %%
d={"Name":"Python","Type":"Programming Language","Version":3.10, 'd2':{"Name":"abc","type":"xyz","mrp":1000}}
del d["Type"]
print(d)
# Out:
# {'Name': 'Python', 'Version': 3.1, 'd2': {'Name': 'abc', 'type': 'xyz', 'mrp': 1000}}
