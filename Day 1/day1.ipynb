# %%
a="hello"
b="python"
print(a+b)
# Out:
# hellopython

# %%
a="hello"
b="python"
print(a.lower())
# Out:
# hello

# %%
a="hello"
b="python"
print(a.upper()+b.upper())
# Out:
# HELLOPYTHON

# %%
a="hello"
b="python"
print(b.capitalize())
# Out:
# Python

# %%
a="hello"
b="python"
print(b.casefold())
# Out:
# python

# %%
a="hello"
b="python"
print(a.center(110))
# Out:
#                                                     hello

# %%
a="hello my name is puneet"
b="python"
print(a.count("puneet"))
# Out:
# 1

# %%
d="hello my name is puneet"
b="python"
print(d.count("puneet"))
# Out:
# 1

# %%
a="hello my name is puneet"
b="python"
print(b.isalpha())
# Out:
# True

# %%
a="hello my name is puneet"
b="python"
print(a.isnumeric())
# Out:
# False

# %%
a="hello my name is puneet"
b="python"
print(a.join(b))
# Out:
# phello my name is puneetyhello my name is puneetthello my name is puneethhello my name is puneetohello my name is puneetn

# %%
a="hello my name is puneet"
b="python"
print(a.ljust(100))
# Out:
# hello my name is puneet

# %%
a="hello my name is puneet"
b="python"
print(b.rjust(50))
# Out:
#                                             python

# %%
a="hello my name is puneet"
b="python"
print(a.lstrip())
# Out:
# hello my name is puneet

# %%
a="hello my name is puneet"
b="python"
print(a.replace("my","your"))
# Out:
# hello your name is puneet

# %%
l= "tipon"
e = "12345"
str="this is python!!!"
encoding=str.maketrans(l,e)
print((str.translate(encoding)))
# Out:
# 1h2s 2s 3y1h45!!!

# %%
a=10
b=20

print(not a!=b)
# Out:
# False

# %%
a="hello my name is puneet"
b="python"
if(b in a):
    print("b is the substring of a")
else:
    print("b is not the substring of a")
# Out:
# false

# %%
a="hello my name is puneet"
b="python"
if(a.isalnum()):
    print("a is alphanumeric")
else:
    print("a is not alphanumeric")
# Out:
# a is not alphanumeric

# %%
#for loop
#for i in range(1,7,2):
 #   print(i)
for i in range(10,0,-1):
    if(i<5):
        break 
    print(i)
# Out:
# 10
# 9
# 8
# 7
# 6
# 5

# %%
x=int(input("enter the number"))
for n in range(0,11):
    print(x,"*",n,"=",x*n)
# Out:
# 6 * 0 = 0
# 6 * 1 = 6
# 6 * 2 = 12
# 6 * 3 = 18
# 6 * 4 = 24
# 6 * 5 = 30
# 6 * 6 = 36
# 6 * 7 = 42
# 6 * 8 = 48
# 6 * 9 = 54
# 6 * 10 = 60

# %%
for i in range(10,0,-1):
    for j in range(5):
        print(i,j,sep="--")
# Out:
# 10--0
# 10--1
# 10--2
# 10--3
# 10--4
# 9--0
# 9--1
# 9--2
# 9--3
# 9--4
# 8--0
# 8--1
# 8--2
# 8--3
# 8--4
# 7--0
# 7--1
# 7--2
# 7--3
# 7--4
# 6--0
# 6--1
# 6--2
# 6--3
# 6--4
# 5--0
# 5--1
# 5--2
# 5--3
# 5--4
# 4--0
# 4--1
# 4--2
# 4--3
# 4--4
# 3--0
# 3--1
# 3--2
# 3--3
# 3--4
# 2--0
# 2--1
# 2--2
# 2--3
# 2--4
# 1--0
# 1--1
# 1--2
# 1--3
# 1--4

# %%
str="hello my name is puneet"
print(str[-1::-1])
# Out:
# teenup si eman ym olleh

# %%
str="hello my name is puneet"
c=0
for x in str:
    print(x)
    c=c+1
print("the length of the string is",c)
# Out:
# h
# e
# l
# l
# o
#
# m
# y
#
# n
# a
# m
# e
#
# i
# s
#
# p
# u
# n
# e
# e
# t
# the length of the string is 23

# %%
#print(chr(77))
print(ord("A"))
# Out:
# 65
