# %%
name=input("enter the student name:")
student_class=input("enter the student class:")

sub1=float(input("enter the marks of subject 1:"))
sub2=float(input("enter the marks of subject 2:"))
sub3=float(input("enter the marks of subject 3:"))      
sub4=float(input("enter the marks of subject 4:"))
sub5=float(input("enter the marks of subject 5:"))  

total_marks=sub1+sub2+sub3+sub4+sub5
percentage=(total_marks/500)*100

print("\n----RESULT----")
print("Name of student:", name)
print("Class:", student_class)
print("Total Marks:", total_marks)
print("Percentage:", percentage)
# Out:
# ----RESULT----
# Name of student: eafaev
# Class: 4
# Total Marks: 201.0
# Percentage: 40.2

# %%
str1=input("enter the first string:")
str2=input("enter the second string:")
c= str1 + " " + str2
#print("Concatenated string:", c)

print("lower",c.lower())
print("upper",c.upper())
print("title",c.title())
print("swapcase",c.swapcase())
print("casefold",c.casefold())
print("Center:", c.center(50))
print("Count of 'a':", c.count('a'))
print("Endswith:", c.endswith("a"))
print("Find:", c.find("a"))
print("Isalnum:", c.isalnum())
print("Isdigit:", c.isdigit())
print("Isnumeric:", c.isnumeric())
print("Isspace:", c.isspace())
print("Replace:", c.replace("a", "@"))
# Out:
# lower jbjb python
# upper JBJB PYTHON
# title Jbjb Python
# swapcase JBJB PYTHON
# casefold jbjb python
# Center:                    jbjb python
# Count of 'a': 0
# Endswith: False
# Find: -1
# Isalnum: False
# Isdigit: False
# Isnumeric: False
# Isspace: False
# Replace: jbjb python

# %%
a = 10

print("Initial Value:", a)

a += 5
print("After += :", a)

a -= 3
print("After -= :", a)

a *= 2
print("After *= :", a)

a /= 4
print("After /= :", a)

a %= 3
print("After %= :", a)
# Out:
# Initial Value: 10
# After += : 15
# After -= : 12
# After *= : 24
# After /= : 6.0
# After %= : 0.0

# %%
name=input("enter the student name:")

sub1=float(input("enter the marks of subject 1:"))
sub2=float(input("enter the marks of subject 2:"))  
sub3=float(input("enter the marks of subject 3:"))
sub4=float(input("enter the marks of subject 4:"))
sub5=float(input("enter the marks of subject 5:"))  
total_marks=sub1+sub2+sub3+sub4+sub5
percentage=(total_marks/500)*100

if percentage >=60:
    grade='A'
elif percentage >=50 and percentage <60:
    grade='B'
elif percentage >=40 and percentage <50:
    grade='C' 
elif percentage >=33 and percentage <40:
    grade='D'
else:
    grade='Fail'        
    

print(f"\n----RESULT----")
print(f"Student Name: {name}")
print(f"Total Marks: {total_marks}")
print(f"Percentage: {percentage:.2f}%")
print(f"Grade: {grade}")
# Out:
# ----RESULT----
# Student Name: puneet
# Total Marks: 317.0
# Percentage: 63.40%
# Grade: A
